# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit792A/Coefficient-Prediction-using-ML/blob/main/Web_scraping_Automated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Installations**

# %%
# !pip install nest-asyncio

# %%
# !pip install pydantic

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 15.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
# !pip install playwright
# !playwright install
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 25.7 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# ...

# %%
pip install autoscraper

# %% [markdown]
# # **Imports**

# %%
import asyncio
import pprint

from bs4 import BeautifulSoup

import nest_asyncio
nest_asyncio.apply()

from playwright.async_api import async_playwright


from pydantic import BaseModel

import os

# from dotenv import load_dotenv
# load_dotenv()
import langchain
from langchain.chains import (create_extraction_chain,
                              create_extraction_chain_pydantic)
from langchain.chat_models import ChatOpenAI

# %% [markdown]
# # **Scraping Part**

# %%
def remove_unwanted_tags(html_content, unwanted_tags=["script", "style"]):
    """
    This removes unwanted HTML tags from the given HTML content.
    """
    soup = BeautifulSoup(html_content, 'html.parser')

    for tag in unwanted_tags:
        for element in soup.find_all(tag):
            element.decompose()

    return str(soup)

# %%
def remove_unessesary_lines(content):
    # Split content into lines
    lines = content.split("\n")

    # Strip whitespace for each line
    stripped_lines = [line.strip() for line in lines]

    # Filter out empty lines
    non_empty_lines = [line for line in stripped_lines if line]

    # Remove duplicated lines (while preserving order)
    seen = set()
    deduped_lines = [line for line in non_empty_lines if not (
        line in seen or seen.add(line))]

    # Join the cleaned lines without any separators (remove newlines)
    cleaned_content = "".join(deduped_lines)

    return cleaned_content

# %%
def extract_tags(html_content, tags: list[str]):
    """
    This takes in HTML content and a list of tags, and returns a string
    containing the text content of all elements with those tags, along with their href attribute if the
    tag is an "a" tag.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    text_parts = []

    for tag in tags:
        elements = soup.find_all(tag)
        for element in elements:
            # If the tag is a link (a tag), append its href as well
            if tag == "a":
                href = element.get('href')
                if href:
                    text_parts.append(f"{element.get_text()} ({href})")
                else:
                    text_parts.append(element.get_text())
            else:
                text_parts.append(element.get_text())

    return ' '.join(text_parts)

# %%
# edit tags to div, tr, th, li, ul, etc...
async def ascrape_playwright(url, tags: list[str] = ["h1", "h2", "h3", "span"]) -> str:
    """
    An asynchronous Python function that uses Playwright to scrape
    content from a given URL, extracting specified HTML tags and removing unwanted tags and unnecessary
    lines.
    """
    print("Started scraping...")
    results = ""
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        try:
            page = await browser.new_page()
            await page.goto(url)

            page_source = await page.content()

            results = remove_unessesary_lines(extract_tags(remove_unwanted_tags(
                page_source), tags))
            print("Content scraped")
        except Exception as e:
            results = f"Error: {e}"
        await browser.close()
    return results

# %%
# url = "https://www.cartrade.com/hyundai-cars/creta/"

# async def scrape_playwright():
#   results = await ascrape_playwright(url)
#   print(results)

# pprint.pprint(asyncio.run(scrape_playwright()))

# %% [markdown]
# # **Schema**

# %%
car_schema = {
    "properties": {
        "name": {"type": "string"},
        "Price": {"type": "number"},
        "Fuel Type": {"type": "string"},
        "Transmission": {"type": "string"},
        "Mileage": {"type": "number"},
        "Engine Size": {"type": "number"},
        "Seating Capacity": {"type": "number"},
        "Size": {"type": "number"},
        "Fuel Tank": {"type": "number"}

    },
    "required": ["name", "Price","Fuel Type","Transmission","Mileage","Engine Size","Seating Capacity","Size","Fuel Tank"],
}

# %%
# class CarSchema(BaseModel):
#     name: str
#     price: float
#     fuel_type: str

# %%
# class Config:
#         model_config = {
#             "title": "Car",
#         }

# %%
# from dataclasses import dataclass
# from pydantic import BaseModel

# ecommerce_schema = {
#     "properties": {
#         "news_headline": {"type": "string"},
#         "news_short_summary": {"type": "string"}
#         # "item_extra_info": {"type": "string"}
#     },
#     # "required": ["news_headline", "news_short_summary"],
#     # , "item_extra_info"],
# }


# class SchemaNewsWebsites(BaseModel):
#     news_headline: str
#     news_short_summary: str

# %% [markdown]
# # **AI Part**

# %%
openai_api_key = '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'

# %%
llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613",
                 openai_api_key=openai_api_key)


def extract(content: str, **kwargs):
    """
    The `extract` function takes in a string `content` and additional keyword arguments, and returns the
    extracted data based on the provided schema.
    """

    # This part just formats the output from a Pydantic class to a Python dictionary for easier reading. Feel free to remove or tweak this.
    if 'schema_pydantic' in kwargs:
        response = create_extraction_chain_pydantic(
            pydantic_schema=kwargs["schema_pydantic"], llm=llm).run(content)
        response_as_dict = [item.dict() for item in response]

        return response_as_dict
    else:
        return create_extraction_chain(schema=kwargs["schema"], llm=llm).run(content)

# %%
# from bard import Bard
# import google.generativeai as genai
# from google.colab import userdata
# import os

# os.environ['GOOGLE_API_KEY '] = "AIzaSyCHdLkIqxWx9vLAaYcah5bZKYJIVm2CK_A"
# genai.configure(api_key="AIzaSyBiNfEFEM8X7zAA0M5zxKn3VowX9sH0nME")
# gemini_api_secret_name = 'AIzaSyCHdLkIqxWx9vLAaYcah5bZKYJIVm2CK_A'

# # bard = Bard(token="YOUR_BARD_API_KEY")  # Replace with your actual Bard API key
# def extract(content: str, **kwargs):
#     if 'schema_pydantic' in kwargs:
#         try:  # Include a try-except block to handle potential errors gracefully
#             response = bard.ask(
#                 query=f"Extract the following information from the text: {content}",
#                 schema=kwargs["schema_pydantic"],
#                 # Other Bard-specific options (if needed)
#             )
#         except Exception as e:
#             print(f"Error during extraction: {e}")
#             response = []  # Handle errors as appropriate, e.g., return an empty list
#     else:
#         try:
#             response = bard.ask(
#                 query=f"Extract the following information from the text: {content}",
#                 schema=kwargs["schema"],
#                 # Other Bard-specific options (if needed)
#             )
#         except Exception as e:
#             print(f"Error during extraction: {e}")
#             response = []

#     # Process Bard's response (if necessary)
#     return response

# %% [markdown]
# # **Automated Extraction**

# %%
wsj_url = "https://www.cartrade.com/hyundai-cars/creta/"

# %%
token_limit = 2000

# %%
async def scrape_with_playwright(url: str, tags, **kwargs):
        html_content = await ascrape_playwright(url, tags)

        print("Extracting content with LLM")

        html_content_fits_context_window_llm = html_content[:token_limit]

        extracted_content = extract(**kwargs,
                                    content=html_content_fits_context_window_llm)

        pprint.pprint(extracted_content)
        return extracted_content

# %%
a = asyncio.run(scrape_with_playwright(
        url=wsj_url,
        tags=["td","tr","th","h2"],
        # schema_pydantic=SchemaNewsWebsites,
        schema=car_schema,
    ))
# Out:
# Started scraping...
# Content scraped
# Extracting content with LLM
# [{'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 11.0,
#   'Transmission': 'Manual',
#   'name': 'E 1.5 Petrol'},
#  {'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 12.18,
#   'Transmission': 'Manual',
#   'name': 'EX 1.5 Petrol'},
#  {'Engine Size': 1493,
#   'Fuel Type': 'Diesel',
#   'Price': 12.45,
#   'Transmission': 'Manual',
#   'name': 'E 1.5 Diesel'},
#  {'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 13.39,
#   'Transmission': 'Manual',
#   'name': 'S 1.5 Petrol'},
#  {'Engine Size': 1493,
#   'Fuel Type': 'Diesel',
#   'Price': 13.68,
#   'Transmission': 'Manual',
#   'name': 'EX 1.5 Diesel'},
#  {'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 14.32,
#   'Transmission': 'Manual',
#   'name': 'S (O) 1.5 Petrol'},
#  {'Engine Size': 1493,
#   'Fuel Type': 'Diesel',
#   'Price': 14.89,
#   'Transmission': 'Manual',
#   'name': 'S 1.5 Diesel'},
# ...

# %%
#added code for multiple URL
#to fetch all the different urls from the web page
from autoscraper import AutoScraper
UrlToScrap="https://www.cartrade.com/new-car-launches/"
WantedList= ["https://www.cartrade.com/hyundai-cars/creta/"]

InfoScraper = AutoScraper()
x = InfoScraper.build(UrlToScrap, wanted_list=WantedList)

temp = []
for i in x :
  UrlToScrap= i
  WantedList= ["https://www.cartrade.com/hyundai-cars/creta/"]

  InfoScraper = AutoScraper()
  k = InfoScraper.build(UrlToScrap, wanted_list=WantedList)
  temp.extend(k)

temp2  = {}
temp2 = list(set(temp))

# %%
main = []
for url in temp2:
  a = asyncio.run(scrape_with_playwright(
        url=wsj_url,
        tags=["td","tr","th","h2"],
        # schema_pydantic=SchemaNewsWebsites,
        schema=car_schema,
    ))
  main.append(ascrape_playwright)
# Out:
# Started scraping...
# Content scraped
# Extracting content with LLM
# [{'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 11.0,
#   'Transmission': 'Manual',
#   'name': 'E 1.5 Petrol'},
#  {'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 12.18,
#   'Transmission': 'Manual',
#   'name': 'EX 1.5 Petrol'},
#  {'Engine Size': 1493,
#   'Fuel Type': 'Diesel',
#   'Price': 12.45,
#   'Transmission': 'Manual',
#   'name': 'E 1.5 Diesel'},
#  {'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 13.39,
#   'Transmission': 'Manual',
#   'name': 'S 1.5 Petrol'},
#  {'Engine Size': 1493,
#   'Fuel Type': 'Diesel',
#   'Price': 13.68,
#   'Transmission': 'Manual',
#   'name': 'EX 1.5 Diesel'},
#  {'Engine Size': 1497,
#   'Fuel Type': 'Petrol',
#   'Price': 14.32,
#   'Transmission': 'Manual',
#   'name': 'S (O) 1.5 Petrol'},
#  {'Engine Size': 1493,
#   'Fuel Type': 'Diesel',
#   'Price': 14.89,
#   'Transmission': 'Manual',
#   'name': 'S 1.5 Diesel'},
# ...

# %%
# Out:
# [{'name': 'E 1.5 Petrol',
#   'Price': 11.0,
#   'Fuel Type': 'Petrol',
#   'Transmission': 'Manual',
#   'Engine Size': 1497},
#  {'name': 'EX 1.5 Petrol',
#   'Price': 12.18,
#   'Fuel Type': 'Petrol',
#   'Transmission': 'Manual',
#   'Engine Size': 1497},
#  {'name': 'E 1.5 Diesel',
#   'Price': 12.45,
#   'Fuel Type': 'Diesel',
#   'Transmission': 'Manual',
#   'Engine Size': 1493},
#  {'name': 'S 1.5 Petrol',
#   'Price': 13.39,
#   'Fuel Type': 'Petrol',
#   'Transmission': 'Manual',
#   'Engine Size': 1497},
#  {'name': 'EX 1.5 Diesel',
#   'Price': 13.68,
#   'Fuel Type': 'Diesel',
#   'Transmission': 'Manual',
#   'Engine Size': 1493},
#  {'name': 'S (O) 1.5 Petrol',
#   'Price': 14.32,
#   'Fuel Type': 'Petrol',
#   'Transmission': 'Manual',
#   'Engine Size': 1497},
#  {'name': 'S 1.5 Diesel',
#   'Price': 14.89,
#   'Fuel Type': 'Diesel',
#   'Transmission': 'Manual',
#   'Engine Size': 1493},
#  {'name': 'SX 1.5 Petrol',
#   'Price': 15.27,
#   'Fuel Type': 'Petrol',
# ...

# %%
loop = asyncio.get_running_loop()

# %%
asyncio.get_event_loop()
# Out:
# <_UnixSelectorEventLoop running=True closed=False debug=False>

# %%
loop.stop()

# %%
while loop.is_closed():
  asyncio.run(scrape_with_playwright(
        url=wsj_url,
        tags=["span"],
        schema_pydantic=SchemaNewsWebsites
    ))
else:
  print("wait")
# Out:
# wait

# %%
loop.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-0eb5f620fced> in <cell line: 1>()
# ----> 1 loop.stop()
#
# NameError: name 'loop' is not defined

# %%
# use loop for multiple urls and schemas for different products and give different tags
asyncio.run(scrape_with_playwright(
        url=wsj_url,
        tags=["span"],
        schema_pydantic=SchemaNewsWebsites
    ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d93f50a302b3> in <cell line: 2>()
#       1 # use loop for multiple urls and schemas for different products and give different tags
# ----> 2 asyncio.run(scrape_with_playwright(
#       3         url=wsj_url,
#       4         tags=["span"],
#       5         schema_pydantic=SchemaNewsWebsites
#
# NameError: name 'asyncio' is not defined

# %%
a
# Out:
# <coroutine object scrape_with_playwright at 0x7b35127074c0>

# %%
import asyncio

async def main():
    scrape_with_playwright(
        url=wsj_url,
        tags=["th","td"],
        schema_pydantic=CarSchema
    )

# Get the current event loop
loop = asyncio.get_event_loop()

# Run the main function on the current event loop
asyncio.run(main(), loop=loop)
# Out:
# <ipython-input-29-f6fd4d280c17>:14: RuntimeWarning: coroutine 'main' was never awaited
#   asyncio.run(main(), loop=loop)
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-f6fd4d280c17> in <cell line: 14>()
#      12
#      13 # Run the main function on the current event loop
# ---> 14 asyncio.run(main(), loop=loop)
#
# TypeError: run() got an unexpected keyword argument 'loop'

# %%
from openai import OpenAI
import time

client = OpenAI(api_key = "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")

adam_NPC = client.beta.assistants.create(
    name = "Adam",
    instructions = "You are an adventurer and want to buy things for your next adventure that require crossing mountains, rivers, marsh, icelands etc and killing various types of monsters, come up with what you need to buy yourself.",
    tools = [{"type": "code_interpreter"}],
    model = "gpt-3.5-turbo"
)
drake_NPC = client.beta.assistants.create(
    name = "Drake",
    instructions = "You are a smith and own a shop selling quality materials of varied needs of adventurers, come up with cost of each item yourself measured in gold coins.",
    tools = [{"type": "code_interpreter"}],
    model = "gpt-3.5-turbo"
)

thread_adam = client.beta.threads.create()
thread_drake = client.beta.threads.create()

def message_adam(prompt):
    message = client.beta.threads.messages.create(
        thread_id = thread_adam.id,
        role = "user",
        content = prompt
    )

    run_adam = client.beta.threads.runs.create(
        thread_id = thread_adam.id,
        assistant_id = adam_NPC.id
    )

    run_adam = client.beta.threads.runs.retrieve(
        thread_id = thread_adam.id,
        run_id = run_adam.id
    )

    while run_adam.status != "completed":
        # print("ran A")
        run_adam = client.beta.threads.runs.retrieve(
        thread_id = thread_adam.id,
        run_id = run_adam.id
        )
    # print("over A")

    msg_adam = client.beta.threads.messages.list(
        thread_id = thread_adam.id
    )

    reply_adam = msg_adam.data[0]
    reply = reply_adam.content[0].text.value
    return reply

def message_drake(prompt):
    message = client.beta.threads.messages.create(
        thread_id = thread_drake.id,
        role = "user",
        content = prompt
    )

    run_drake = client.beta.threads.runs.create(
        thread_id = thread_drake.id,
        assistant_id = drake_NPC.id
    )

    run_drake = client.beta.threads.runs.retrieve(
        thread_id = thread_drake.id,
        run_id = run_drake.id
    )

    while run_drake.status != "completed":
        # print("ran D")
        run_drake = client.beta.threads.runs.retrieve(
        thread_id = thread_drake.id,
        run_id = run_drake.id
        )
    # print("over D")

    msg_drake = client.beta.threads.messages.list(
        thread_id = thread_drake.id
    )

    reply_drake = msg_drake.data[0]
    reply = reply_drake.content[0].text.value
    return reply

print("adam: Hello, I want you some things for my adventure.\n")
reply_drake = message_drake("Hello, I want to you buy a armour.")

if __name__ == '__main__':
    try:
        while True:
            time.sleep(30)
            print("drake:", reply_drake, "\n")
            reply_adam = message_adam(reply_drake)
            time.sleep(30)
            print("adam:", reply_adam, "\n")
            reply_drake = message_drake(reply_adam)

            # prompt = input("user: ")
            # print("drake:", message_drake(prompt))

    except KeyboardInterrupt:
        client.beta.assistants.delete(
            assistant_id = adam_NPC.id
        )
        client.beta.assistants.delete(
            assistant_id = drake_NPC.id
        )
# Out:
# adam: Hello, I want you some things for my adventure.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a046e14e063a> in <cell line: 89>()
#      87
#      88 print("adam: Hello, I want you some things for my adventure.\n")
# ---> 89 reply_drake = message_drake("Hello, I want to you buy a armour.")
#      90
#      91 if __name__ == '__main__':
#
# <ipython-input-2-a046e14e063a> in message_drake(prompt)
#      72     while run_drake.status != "completed":
#      73         # print("ran D")
# ---> 74         run_drake = client.beta.threads.runs.retrieve(
#      75         thread_id = thread_drake.id,
#      76         run_id = run_drake.id
#
# /usr/local/lib/python3.10/dist-packages/openai/resources/beta/threads/runs/runs.py in retrieve(self, run_id, thread_id, extra_headers, extra_query, extra_body, timeout)
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Function to extract price from webpage
def extract_price(url):
    # Fetch HTML content
    response = requests.get(url)
    html_content = response.text

    # Parse HTML
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find price element(s)
    price_elements = soup.find_all("span", class_="a-price-whole")

    # Extract price text
    prices = []
    for price_element in price_elements:
        price_text = price_element.get_text(strip=True)
        prices.append(price_text)

    return prices

# Example URL
url = "https://www.amazon.in/ZEBRONICS-Zeb-Rush-Headphone-Neodymium-Red/dp/B08TCB84ZX/ref=sr_1_6?crid=24U42Q1Q6Q8B7&dib=eyJ2IjoiMSJ9.LmqVnWKHzxoanX00AqyPob-VDaBsbXo9UM-HOcZ8cZ0I_Ml36EC0pite7iClDhSInZPMF6dg7wbKEH-t63Mb8EOU6M4WPV9k9w_JkLyWdB1SWbxhk4c3ypPpGQvY1SMAVdklu99I2KXIyUT5Mhi0wIbf3OwCJwsgEkU4cb4TpN9QOjQ4r7tTrPKBjNj0W16vUUQufRSj8EJiNh78Jv6k4sjoyL8nJSl0WBN7xoIGIlUKhO5M5uh71DNFiuF7QeQ4Qe44t2bt4dpoNmuWKLgCfr_EX_mEwfOZId80yFdED3A.hWbLNxHlXgCEyhpcMjgz5SvzNc5OlgSB9DnibAySpG4&dib_tag=se&keywords=headphones+with+mic+for+gaming&qid=1711003565&s=electronics&sprefix=%2Celectronics%2C262&sr=1-6"

# Extract price
prices = extract_price(url)

# Print extracted prices
for idx, price in enumerate(prices, start=1):
    print(f"Price {idx}: {price}")

# %%
prices
# Out:
# []

# %%
# !pip install openai==0.28

# %%
api_key = "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"

# %%
endpoint = "https://api.openai.com/v1/completions"

# %%
import openai

openai.api_key = api_key

response = openai.Completion.create(
    engine="gpt-3.5-turbo-0613",
    prompt="Once upon a time",
    max_tokens=50
)

print(response.choices[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-6-885a6bfae292> in <cell line: 5>()
#       3 openai.api_key = api_key
#       4
# ----> 5 response = openai.Completion.create(
#       6     engine="gpt-3.5-turbo-0613",
#       7     prompt="Once upon a time",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# ...
